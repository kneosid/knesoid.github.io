# %% [markdown]
# 데이터 링크 : [다운로드](https://drive.google.com/file/d/10Am_lQnYbUhACh_z5HKlN-lBRPgoUAFp/view?usp=share_link)

# %%
import pandas as pd
from time import time

# %% [markdown]
# ### Load Transaction data
#
# - pandas로 데이터를 읽어온 뒤, 기본적인 데이터를 확인해봅니다.

# %%
# Load data (pandas version)

start = time()
train = pd.read_csv('./data/transactions_train.csv')
end = time()
print(f'데이터를 불러오는데 걸리는 시간 : {end - start}초')
train
# Out:
# 데이터를 불러오는데 걸리는 시간 : 19.63964581489563초
#                t_dat                                        customer_id  \
# 0         2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 1         2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 2         2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 3         2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 4         2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# ...              ...                                                ...
# 31788319  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 31788320  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 31788321  2020-09-22  fff380805474b287b05cb2a7507b9a013482f7dd0bce0e...
# 31788322  2020-09-22  fff4d3a8b1f3b60af93e78c30a7cb4cf75edaf2590d3e5...
# 31788323  2020-09-22  fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...
#
#           article_id     price  sales_channel_id
# 0          663713001  0.050831                 2
# 1          541518023  0.030492                 2
# 2          505221004  0.015237                 2
# 3          685687003  0.016932                 2
# 4          685687004  0.016932                 2
# ...              ...       ...               ...
# 31788319   929511001  0.059305                 2
# 31788320   891322004  0.042356                 2
# 31788321   918325001  0.043203                 1
# 31788322   833459002  0.006763                 1
# 31788323   898573003  0.033881                 2
#
# [31788324 rows x 5 columns]

# %%
# Check memory usage 

mem_usage = train.memory_usage(deep=True).sum() / 1024 / 1024 / 1024
print(f"Memory Usage : {mem_usage:.4} GiB")
# Out:
# Memory Usage : 6.276 GiB

# %% [markdown]
# ### 데이터를 가져오는 첫번째 방법. parquet
#
# - 훨씬 더 데이터를 빠르게 가져올 수 있는 구조인 parquet 파일로 변환합니다.

# %%
# parquet로 다시 만들어봅시다.

part = pd.read_csv('./data/transactions_train.csv',
                   nrows=1000)      # 1000개만 읽어오기
part
# Out:
#           t_dat                                        customer_id  \
# 0    2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 1    2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 2    2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 3    2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 4    2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# ..          ...                                                ...
# 995  2018-09-20  05943a58bd172641b80919a9bdf14012df940800bc74d0...
# 996  2018-09-20  05943a58bd172641b80919a9bdf14012df940800bc74d0...
# 997  2018-09-20  05943a58bd172641b80919a9bdf14012df940800bc74d0...
# 998  2018-09-20  05943a58bd172641b80919a9bdf14012df940800bc74d0...
# 999  2018-09-20  059d4230aeb70d519fb5e5e5ec8f5efc6c3eaad65b06af...
#
#      article_id     price  sales_channel_id
# 0     663713001  0.050831                 2
# 1     541518023  0.030492                 2
# 2     505221004  0.015237                 2
# 3     685687003  0.016932                 2
# 4     685687004  0.016932                 2
# ..          ...       ...               ...
# 995   661794001  0.152525                 2
# 996   661794001  0.152525                 2
# 997   661794002  0.152525                 2
# 998   661794002  0.152525                 2
# 999   516903005  0.033881                 2
#
# [1000 rows x 5 columns]

# %%
part2 = pd.read_csv('./data/transactions_train.csv',
                   usecols=['t_dat','sales_channel_id'])
part2
# Out:
#                t_dat  sales_channel_id
# 0         2018-09-20                 2
# 1         2018-09-20                 2
# 2         2018-09-20                 2
# 3         2018-09-20                 2
# 4         2018-09-20                 2
# ...              ...               ...
# 31788319  2020-09-22                 2
# 31788320  2020-09-22                 2
# 31788321  2020-09-22                 1
# 31788322  2020-09-22                 1
# 31788323  2020-09-22                 2
#
# [31788324 rows x 2 columns]

# %%
# Check memory usage

mem_usage = part2.memory_usage(deep=True).sum() / 1024 / 1024 / 1024
print(f"Memory Usage : {mem_usage:.4} GiB")
# Out:
# Memory Usage : 2.22 GiB

# %% [markdown]
# ### 데이터를 가져오는 두번째 방법. I/O
#
# - 데이터를 쪼개서 들고와봅시다.

# %%
print(part['sales_channel_id'].value_counts())
# Out:
# 2    716
# 1    284
# Name: sales_channel_id, dtype: int64

# %%
# chunk

sales = part['sales_channel_id'].value_counts() * 0

for chunk in pd.read_csv('./data/transactions_train.csv',
                         chunksize=300000):
    print(chunk['sales_channel_id'].value_counts())
    sales = sales + chunk['sales_channel_id'].value_counts()

sales
# Out:
# 2    226143
# 1     73857
# Name: sales_channel_id, dtype: int64
# 2    165439
# 1    134561
# Name: sales_channel_id, dtype: int64
# 2    194943
# 1    105057
# Name: sales_channel_id, dtype: int64
# 2    201745
# 1     98255
# Name: sales_channel_id, dtype: int64
# 2    220733
# 1     79267
# Name: sales_channel_id, dtype: int64
# 2    203909
# 1     96091
# Name: sales_channel_id, dtype: int64
# 2    217776
# 1     82224
# Name: sales_channel_id, dtype: int64
# 2    211571
# 1     88429
# Name: sales_channel_id, dtype: int64
# 2    220108
# 1     79892
# Name: sales_channel_id, dtype: int64
# 2    213843
# 1     86157
# Name: sales_channel_id, dtype: int64
# 2    214965
# 1     85035
# Name: sales_channel_id, dtype: int64
# 2    206437
# 1     93563
# Name: sales_channel_id, dtype: int64
# 2    197220
# 1    102780
# Name: sales_channel_id, dtype: int64
# 2    162149
# 1    137851
# Name: sales_channel_id, dtype: int64
# 2    185695
# 1    114305
# Name: sales_channel_id, dtype: int64
# 2    224869
# 1     75131
# Name: sales_channel_id, dtype: int64
# 2    230780
# 1     69220
# Name: sales_channel_id, dtype: int64
# 2    217314
# 1     82686
# Name: sales_channel_id, dtype: int64
# 2    212667
# 1     87333
# Name: sales_channel_id, dtype: int64
# 2    213782
# 1     86218
# Name: sales_channel_id, dtype: int64
# 2    205374
# 1     94626
# Name: sales_channel_id, dtype: int64
# 2    189435
# 1    110565
# Name: sales_channel_id, dtype: int64
# 2    192989
# 1    107011
# Name: sales_channel_id, dtype: int64
# 2    219809
# 1     80191
# Name: sales_channel_id, dtype: int64
# 2    233318
# 1     66682
# Name: sales_channel_id, dtype: int64
# 2    211436
# 1     88564
# Name: sales_channel_id, dtype: int64
# 2    208115
# 1     91885
# Name: sales_channel_id, dtype: int64
# 2    220498
# 1     79502
# Name: sales_channel_id, dtype: int64
# 2    219076
# 1     80924
# Name: sales_channel_id, dtype: int64
# 2    202388
# 1     97612
# Name: sales_channel_id, dtype: int64
# 2    208644
# 1     91356
# Name: sales_channel_id, dtype: int64
# 2    200924
# 1     99076
# Name: sales_channel_id, dtype: int64
# 2    204608
# 1     95392
# Name: sales_channel_id, dtype: int64
# 2    213319
# 1     86681
# Name: sales_channel_id, dtype: int64
# 2    216161
# 1     83839
# Name: sales_channel_id, dtype: int64
# 2    192004
# 1    107996
# Name: sales_channel_id, dtype: int64
# 2    210333
# 1     89667
# Name: sales_channel_id, dtype: int64
# 2    209313
# 1     90687
# Name: sales_channel_id, dtype: int64
# 2    209045
# 1     90955
# Name: sales_channel_id, dtype: int64
# 2    212331
# 1     87669
# Name: sales_channel_id, dtype: int64
# 2    217664
# 1     82336
# Name: sales_channel_id, dtype: int64
# 2    213547
# 1     86453
# Name: sales_channel_id, dtype: int64
# 2    202079
# 1     97921
# Name: sales_channel_id, dtype: int64
# 2    207017
# 1     92983
# Name: sales_channel_id, dtype: int64
# 2    185207
# 1    114793
# Name: sales_channel_id, dtype: int64
# 2    188541
# 1    111459
# Name: sales_channel_id, dtype: int64
# 2    203010
# 1     96990
# Name: sales_channel_id, dtype: int64
# 2    214768
# 1     85232
# Name: sales_channel_id, dtype: int64
# 2    215956
# 1     84044
# Name: sales_channel_id, dtype: int64
# 2    198610
# 1    101390
# Name: sales_channel_id, dtype: int64
# 2    212158
# 1     87842
# Name: sales_channel_id, dtype: int64
# 2    207465
# 1     92535
# Name: sales_channel_id, dtype: int64
# 2    204245
# 1     95755
# Name: sales_channel_id, dtype: int64
# 2    206354
# 1     93646
# Name: sales_channel_id, dtype: int64
# 2    213063
# 1     86937
# Name: sales_channel_id, dtype: int64
# 2    210505
# 1     89495
# Name: sales_channel_id, dtype: int64
# 2    204582
# 1     95418
# Name: sales_channel_id, dtype: int64
# 2    245737
# 1     54263
# Name: sales_channel_id, dtype: int64
# 2    220647
# 1     79353
# Name: sales_channel_id, dtype: int64
# 2    211104
# 1     88896
# Name: sales_channel_id, dtype: int64
# 2    186061
# 1    113939
# Name: sales_channel_id, dtype: int64
# 2    208046
# 1     91954
# Name: sales_channel_id, dtype: int64
# 2    220735
# 1     79265
# Name: sales_channel_id, dtype: int64
# 2    198158
# 1    101842
# Name: sales_channel_id, dtype: int64
# 2    229714
# 1     70286
# Name: sales_channel_id, dtype: int64
# 2    244120
# 1     55880
# Name: sales_channel_id, dtype: int64
# 2    200754
# 1     99246
# Name: sales_channel_id, dtype: int64
# 2    179932
# 1    120068
# Name: sales_channel_id, dtype: int64
# 1    151794
# 2    148206
# Name: sales_channel_id, dtype: int64
# 2    187528
# 1    112472
# Name: sales_channel_id, dtype: int64
# 2    225348
# 1     74652
# Name: sales_channel_id, dtype: int64
# 2    210041
# 1     89959
# Name: sales_channel_id, dtype: int64
# 2    201283
# 1     98717
# Name: sales_channel_id, dtype: int64
# 2    210480
# 1     89520
# Name: sales_channel_id, dtype: int64
# 2    213413
# 1     86587
# Name: sales_channel_id, dtype: int64
# 2    197072
# 1    102928
# Name: sales_channel_id, dtype: int64
# 2    214697
# 1     85303
# Name: sales_channel_id, dtype: int64
# 2    218618
# 1     81382
# Name: sales_channel_id, dtype: int64
# 2    274007
# 1     25993
# Name: sales_channel_id, dtype: int64
# 2    300000
# Name: sales_channel_id, dtype: int64
# 2    300000
# Name: sales_channel_id, dtype: int64
# 2    300000
# Name: sales_channel_id, dtype: int64
# 2    300000
# Name: sales_channel_id, dtype: int64
# 2    300000
# Name: sales_channel_id, dtype: int64
# 2    281985
# 1     18015
# Name: sales_channel_id, dtype: int64
# 2    219176
# 1     80824
# Name: sales_channel_id, dtype: int64
# 2    205802
# 1     94198
# Name: sales_channel_id, dtype: int64
# 2    192919
# 1    107081
# Name: sales_channel_id, dtype: int64
# 2    190248
# 1    109752
# Name: sales_channel_id, dtype: int64
# 2    180015
# 1    119985
# Name: sales_channel_id, dtype: int64
# 2    175843
# 1    124157
# Name: sales_channel_id, dtype: int64
# 2    217538
# 1     82462
# Name: sales_channel_id, dtype: int64
# 2    207084
# 1     92916
# Name: sales_channel_id, dtype: int64
# 2    206118
# 1     93882
# Name: sales_channel_id, dtype: int64
# 2    207473
# 1     92527
# Name: sales_channel_id, dtype: int64
# 2    188043
# 1    111957
# Name: sales_channel_id, dtype: int64
# 2    177601
# 1    122399
# Name: sales_channel_id, dtype: int64
# 2    173764
# 1    126236
# Name: sales_channel_id, dtype: int64
# 2    178025
# 1    121975
# Name: sales_channel_id, dtype: int64
# 2    197685
# 1    102315
# Name: sales_channel_id, dtype: int64
# 2    214148
# 1     85852
# Name: sales_channel_id, dtype: int64
# 2    187472
# 1    112528
# Name: sales_channel_id, dtype: int64
# 2    196417
# 1    103583
# Name: sales_channel_id, dtype: int64
# 2    198620
# 1    101380
# Name: sales_channel_id, dtype: int64
# 2    209873
# 1     90127
# Name: sales_channel_id, dtype: int64
# 2    202333
# 1     85991
# Name: sales_channel_id, dtype: int64
# 1           NaN
# 2    22379862.0
# Name: sales_channel_id, dtype: float64

# %% [markdown]
# (OPTIONAL) 데이터를 일부만 따로 저장

# %%
train2006 = train.loc[train['t_dat'] > '2020-06-01']
train2006.to_csv('transactions_202006.csv',index=False)

# %%
train = pd.read_csv('./transactions_202006.csv')
train
# Out:
#               t_dat                                        customer_id  \
# 0        2020-06-02  0001f8cef6b9702d54abf66fd89eb21014bf98567065a9...
# 1        2020-06-02  0001f8cef6b9702d54abf66fd89eb21014bf98567065a9...
# 2        2020-06-02  0015f16aa2702e2ec13d2e38052f496b9b915d3c64e82c...
# 3        2020-06-02  0015f16aa2702e2ec13d2e38052f496b9b915d3c64e82c...
# 4        2020-06-02  001ef7c503e5407b6b836351b0415d3a226c587d4fb17b...
# ...             ...                                                ...
# 5108381  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 5108382  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 5108383  2020-09-22  fff380805474b287b05cb2a7507b9a013482f7dd0bce0e...
# 5108384  2020-09-22  fff4d3a8b1f3b60af93e78c30a7cb4cf75edaf2590d3e5...
# 5108385  2020-09-22  fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...
#
#          article_id     price  sales_channel_id
# 0         855834001  0.015831                 1
# 1         836130002  0.015831                 1
# 2         832453006  0.016932                 1
# 3         841260011  0.016932                 1
# 4         822946002  0.026797                 2
# ...             ...       ...               ...
# 5108381   929511001  0.059305                 2
# 5108382   891322004  0.042356                 2
# 5108383   918325001  0.043203                 1
# 5108384   833459002  0.006763                 1
# 5108385   898573003  0.033881                 2
#
# [5108386 rows x 5 columns]
